# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Reading the dataset

# %%
df=pd.read_csv('day.csv')

# %%
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
df.info() # to check the null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
df.shape
# Out:
# (730, 16)

# %%
df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# # Duplicating the dataframe

# %%
bike_dup = df.copy()
# Checking for duplicates and dropping the entire duplicate row if any
bike_dup.drop_duplicates(subset=None, inplace=True)

# %%
bike_dup.shape
# Out:
# (730, 16)

# %%
df=df.drop(columns=['instant','dteday','casual','registered'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    int64
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    int64
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    int64
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 68.6 KB

# %%
df['season']=df['season'].astype('category')
df['weathersit']=df['weathersit'].astype('category')
df['mnth']=df['mnth'].astype('category')
df['weekday']=df['weekday'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    category
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    category
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    category
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    category
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: category(4), float64(4), int64(4)
# memory usage: 49.7 KB

# %% [markdown]
# # Forming the dummy variables

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            730 non-null    int64
#  1   holiday       730 non-null    int64
#  2   workingday    730 non-null    int64
#  3   temp          730 non-null    float64
#  4   atemp         730 non-null    float64
#  5   hum           730 non-null    float64
#  6   windspeed     730 non-null    float64
#  7   cnt           730 non-null    int64
#  8   season_2      730 non-null    uint8
#  9   season_3      730 non-null    uint8
#  10  season_4      730 non-null    uint8
#  11  mnth_2        730 non-null    uint8
#  12  mnth_3        730 non-null    uint8
#  13  mnth_4        730 non-null    uint8
#  14  mnth_5        730 non-null    uint8
#  15  mnth_6        730 non-null    uint8
#  16  mnth_7        730 non-null    uint8
#  17  mnth_8        730 non-null    uint8
# ...

# %% [markdown]
# # Developing the Model

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, train_size = 0.70, test_size = 0.30, random_state = 333)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 483 to 366
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            510 non-null    int64
#  1   holiday       510 non-null    int64
#  2   workingday    510 non-null    int64
#  3   temp          510 non-null    float64
#  4   atemp         510 non-null    float64
#  5   hum           510 non-null    float64
#  6   windspeed     510 non-null    float64
#  7   cnt           510 non-null    int64
#  8   season_2      510 non-null    uint8
#  9   season_3      510 non-null    uint8
#  10  season_4      510 non-null    uint8
#  11  mnth_2        510 non-null    uint8
#  12  mnth_3        510 non-null    uint8
#  13  mnth_4        510 non-null    uint8
#  14  mnth_5        510 non-null    uint8
#  15  mnth_6        510 non-null    uint8
#  16  mnth_7        510 non-null    uint8
#  17  mnth_8        510 non-null    uint8
# ...

# %% [markdown]
# # Visualising the Numeric Variables

# %%
import matplotlib.pyplot as plt
bike_num=df_train[[ 'temp', 'atemp', 'hum', 'windspeed','cnt']]
sns.pairplot(bike_num, diag_kind='kde')
plt.show()

# %% [markdown]
# # Visualising Categorical variables

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 483 to 366
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            510 non-null    int64
#  1   holiday       510 non-null    int64
#  2   workingday    510 non-null    int64
#  3   temp          510 non-null    float64
#  4   atemp         510 non-null    float64
#  5   hum           510 non-null    float64
#  6   windspeed     510 non-null    float64
#  7   cnt           510 non-null    int64
#  8   season_2      510 non-null    uint8
#  9   season_3      510 non-null    uint8
#  10  season_4      510 non-null    uint8
#  11  mnth_2        510 non-null    uint8
#  12  mnth_3        510 non-null    uint8
#  13  mnth_4        510 non-null    uint8
#  14  mnth_5        510 non-null    uint8
#  15  mnth_6        510 non-null    uint8
#  16  mnth_7        510 non-null    uint8
#  17  mnth_8        510 non-null    uint8
# ...

# %%
plt.figure(figsize=(25, 10))
plt.subplot(2,3,1)
sns.boxplot(x = 'season', y = 'cnt', data = bike_dup)
plt.subplot(2,3,2)
sns.boxplot(x = 'mnth', y = 'cnt', data = bike_dup)
plt.subplot(2,3,3)
sns.boxplot(x = 'weathersit', y = 'cnt', data = bike_dup)
plt.subplot(2,3,4)
sns.boxplot(x = 'holiday', y = 'cnt', data = bike_dup)
plt.subplot(2,3,5)
sns.boxplot(x = 'weekday', y = 'cnt', data = bike_dup)
plt.subplot(2,3,6)
sns.boxplot(x = 'workingday', y = 'cnt', data = bike_dup)
plt.show()

# %% [markdown]
# # Finding the correlation

# %%
plt.figure(figsize = (25,20))
sns.heatmap(bike_dup.corr(), annot = True, cmap="RdBu")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
scaler = StandardScaler()

# %%
df_train.head()
# Out:
#      yr  holiday  workingday       temp     atemp      hum  windspeed   cnt  \
# 483   1        0           0  18.791653  22.50605  58.7083   7.832836  6304
# 650   1        0           0  16.126653  19.56980  49.4583   9.791514  7109
# 212   0        0           1  31.638347  35.16460  55.0833  10.500039  4266
# 714   1        0           0  14.862500  18.49690  83.8750   6.749714  3786
# 8     0        0           0   5.671653   5.80875  43.4167  24.250650   822
#
#      season_2  season_3  ...  mnth_11  mnth_12  weekday_1  weekday_2  \
# 483         1         0  ...        0        0          0          0
# 650         0         0  ...        0        0          0          0
# 212         0         1  ...        0        0          1          0
# 714         0         0  ...        0        1          0          0
# 8           0         0  ...        0        0          0          0
#
#      weekday_3  weekday_4  weekday_5  weekday_6  weathersit_2  weathersit_3
# ...

# %%
df_train.columns
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'cnt', 'season_2', 'season_3', 'season_4', 'mnth_2', 'mnth_3', 'mnth_4',
#        'mnth_5', 'mnth_6', 'mnth_7', 'mnth_8', 'mnth_9', 'mnth_10', 'mnth_11',
#        'mnth_12', 'weekday_1', 'weekday_2', 'weekday_3', 'weekday_4',
#        'weekday_5', 'weekday_6', 'weathersit_2', 'weathersit_3'],
#       dtype='object')

# %% [markdown]
# # Transforming the dataset

# %%
num_vars = ['temp', 'atemp', 'hum', 'windspeed','cnt']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df_train.columns
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'cnt', 'season_2', 'season_3', 'season_4', 'mnth_2', 'mnth_3', 'mnth_4',
#        'mnth_5', 'mnth_6', 'mnth_7', 'mnth_8', 'mnth_9', 'mnth_10', 'mnth_11',
#        'mnth_12', 'weekday_1', 'weekday_2', 'weekday_3', 'weekday_4',
#        'weekday_5', 'weekday_6', 'weathersit_2', 'weathersit_3'],
#       dtype='object')

# %%
df_train
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 483   1        0           0 -0.190954 -0.133896 -0.250264  -0.946034
# 650   1        0           0 -0.546695 -0.495089 -0.892777  -0.569618
# 212   0        0           1  1.523904  1.423253 -0.502060  -0.433454
# 714   1        0           0 -0.715442 -0.627068  1.497837  -1.154187
# 8     0        0           0 -1.942294 -2.187858 -1.312432   2.209121
# ..   ..      ...         ...       ...       ...       ...        ...
# 467   1        0           1 -0.277607 -0.246532 -1.491877  -0.449498
# 444   1        0           1  0.210399  0.254433  1.376281  -1.298188
# 46    0        0           1 -0.957559 -0.957588 -1.386679   0.790716
# 374   1        0           1 -1.009908 -0.941437  0.162605  -0.036424
# 366   1        1           0 -1.205034 -1.350586 -1.679623   1.793420
#
#           cnt  season_2  season_3  ...  mnth_11  mnth_12  weekday_1  \
# ...

# %%
X_train=df_train.drop(columns=['cnt','holiday','hum','weekday_1','workingday','weekday_2','weekday_3','temp','weekday_4','weekday_5','weekday_6','mnth_2','mnth_3','mnth_4','mnth_5','mnth_6','mnth_7','mnth_8','weathersit_2','mnth_11','mnth_12'])
y_train=df_train['cnt']

# %%
lm=LinearRegression()
lm.fit(X_train,y_train)
rfe = RFE(lm, n_features_to_select=15)             # running RFE
rfe = rfe.fit(X_train, y_train)
col = X_train.columns[rfe.support_]
col
X_train_rfe = X_train[col]
import statsmodels.api as sm  
X_train_rfe = sm.add_constant(X_train_rfe)
ols_model= sm.OLS(y_train,X_train_rfe).fit()

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('yr', True, 1),
#  ('atemp', True, 1),
#  ('windspeed', True, 1),
#  ('season_2', True, 1),
#  ('season_3', True, 1),
#  ('season_4', True, 1),
#  ('mnth_9', True, 1),
#  ('mnth_10', True, 1),
#  ('weathersit_3', True, 1)]

# %%
ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     219.0
# Date:                Sat, 17 Dec 2022   Prob (F-statistic):          3.33e-167
# Time:                        19:33:16   Log-Likelihood:                -316.23
# No. Observations:                 510   AIC:                             652.5
# Df Residuals:                     500   BIC:                             694.8
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Checking the Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#        Features   VIF
# 4      season_3  2.20
# 5      season_4  1.98
# 1         atemp  1.79
# 0            yr  1.76
# 7       mnth_10  1.62
# 3      season_2  1.28
# 6        mnth_9  1.26
# 2     windspeed  1.10
# 8  weathersit_3  1.06

# %% [markdown]
# # transforming the testing data

# %%
df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
df_test
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 22    0        0           0 -2.171125 -2.294484 -1.296074   0.723877
# 468   1        0           0  0.009723  0.099057 -0.834889   0.006904
# 553   1        0           0  1.802110  1.958993 -0.342876  -0.833743
# 504   1        0           0  0.698399  0.689335 -0.643871   0.823885
# 353   0        0           1 -0.587742 -0.463979 -0.192375  -1.658554
# ..   ..      ...         ...       ...       ...       ...        ...
# 237   0        0           1  1.131675  1.155339  0.959515  -1.370239
# 611   1        0           1  1.273057  1.322358  0.916102   0.591525
# 258   0        0           1 -0.131660 -0.064062 -0.227106  -0.337322
# 518   1        0           0  0.598063  0.635000 -0.901460  -0.081039
# 313   0        0           1 -0.619665 -0.603801  1.321289  -0.016916
#
#           cnt  season_2  season_3  ...  mnth_11  mnth_12  weekday_1  \
# ...

# %%
X_test=df_test.drop(columns=['cnt','holiday','hum','weekday_1','workingday','weekday_2','weekday_3','temp','weekday_4','weekday_5','weekday_6','mnth_2','mnth_3','mnth_4','mnth_5','mnth_6','mnth_7','mnth_8','weathersit_2','mnth_11','mnth_12'])
y_test=df_test['cnt']

# %%
X_test_sm=sm.add_constant(X_test)

# %%
y_test_pred=ols_model.predict(X_test_sm)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.7907924128916937
